# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Machine_Learning_Practice/yolov7/yolov7-custom
# Out:
# /content/drive/MyDrive/Machine_Learning_Practice/yolov7/yolov7-custom

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Machine_Learning_Practice/yolov7/yolov7-custom

# %%
# !python train.py --workers 1 --device 0 --batch-size 8 --epochs 100 --img 640 640 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --name yolov7-custom --weights yolov7.pt
# Out:
# YOLOR 🚀 2022-8-23 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=8, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', device='0', entity=None, epochs=100, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.custom.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7-custom', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov7-custom12', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=8, upload_dataset=False, weights='yolov7.pt', workers=1, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Detect .jpg
# !python detect.py --weights yolov7_custom.pt --conf 0.5 --img-size 640 --source do_01.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='do_01.jpg', update=False, view_img=False, weights=['yolov7_custom.pt'])
# YOLOR 🚀 2022-8-23 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36503348 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# Detect .mp4
# !python detect.py --weights yolov7_custom.pt --conf 0.5 --img-size 640 --source 哆啦A夢.mp4
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# video 1/1 (14312/19310) /content/drive/MyDrive/Machine_Learning_Practice/yolov7/yolov7-custom/哆啦A夢.mp4: 1 Noby, 1 Sue, Done. (10.9ms) Inference, (1.1ms) NMS
# video 1/1 (14313/19310) /content/drive/MyDrive/Machine_Learning_Practice/yolov7/yolov7-custom/哆啦A夢.mp4: 1 Noby, 1 Sue, Done. (11.7ms) Inference, (0.8ms) NMS
# video 1/1 (14314/19310) /content/drive/MyDrive/Machine_Learning_Practice/yolov7/yolov7-custom/哆啦A夢.mp4: 1 Noby, 1 Sue, Done. (11.7ms) Inference, (0.8ms) NMS
# video 1/1 (14315/19310) /content/drive/MyDrive/Machine_Learning_Practice/yolov7/yolov7-custom/哆啦A夢.mp4: 1 Noby, 1 Sue, Done. (12.6ms) Inference, (0.8ms) NMS
# video 1/1 (14316/19310) /content/drive/MyDrive/Machine_Learning_Practice/yolov7/yolov7-custom/哆啦A夢.mp4: 1 Noby, 1 Sue, Done. (17.8ms) Inference, (1.1ms) NMS
# video 1/1 (14317/19310) /content/drive/MyDrive/Machine_Learning_Practice/yolov7/yolov7-custom/哆啦A夢.mp4: 1 Noby, 1 Sue, Done. (12.0ms) Inference, (0.8ms) NMS
# ...
